# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import scipy.stats as stats

# %%
f_stats = 8.78 
df1 = 2
df2 = 15

# %%
p_value = stats.f.sf(f_stats, df1, df2)
print("P-Value (Significant Level) : ", p_value)
# Out:
# P-Value (Significant Level) :  0.002989175894193495

# %% [markdown]
# # Chi-Square Test

# %%
from scipy.stats import chisquare

# %%
dataset = pd.read_csv('ANOVA_TESTING_R.csv')
dataset.head()
# Out:
#   Dosage  Alertness
# 0      a         30
# 1      a         38
# 2      a         35
# 3      a         41
# 4      a         27

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
model = ols('Alertness ~ Dosage', data=dataset).fit()
anova_result = sm.stats.anova_lm(model)
print(anova_result)
# Out:
#             df  sum_sq  mean_sq        F    PR(>F)
# Dosage     2.0  426.25  213.125  8.78866  0.002977
# Residual  15.0  363.75   24.250      NaN       NaN
