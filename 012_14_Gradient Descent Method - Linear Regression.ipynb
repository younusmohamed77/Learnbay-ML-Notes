# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_regression

# %%
x, y = make_regression(n_samples=4, n_features=1, n_informative=1, n_targets=1, noise=80, random_state=1)

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)

# %%
# Building OLS method
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([-50.61708585])

# %%
reg.intercept_
# Out:
# -45.44115263199091

# %%
plt.scatter(x,y)
plt.plot(x, reg.predict(x), color='red')

# %%
# y = m*x +c , m = slope, c = intercept , gradeint descent = learning_rate
m = 78.35
c = 100
learning_rate = 0.1
loss_slope =
